-- %%
USE CATALOG workspace;
USE SCHEMA sim_retail_demo;

-- %% [markdown]
-- # Drop LDP Tables from SQL

-- %%
DROP TABLE IF EXISTS workspace.sim_retail_demo.customer_bronze_ldp;
DROP TABLE IF EXISTS workspace.sim_retail_demo.customer_bronze_clean_ldp;
DROP TABLE IF EXISTS workspace.sim_retail_demo.customer_silver_ldp;
DROP MATERIALIZED VIEW IF EXISTS workspace.sim_retail_demo.gold_customer_order_history_ldp;
DROP MATERIALIZED VIEW IF EXISTS workspace.sim_retail_demo.gold_orders_by_city_state_ldp;
DROP MATERIALIZED VIEW IF EXISTS workspace.sim_retail_demo.gold_returns_by_customer_ldp;
DROP TABLE IF EXISTS workspace.sim_retail_demo.orders_bronze_ldp;
DROP TABLE IF EXISTS workspace.sim_retail_demo.orders_silver_ldp;
DROP TABLE IF EXISTS workspace.sim_retail_demo.status_bronze_ldp;
DROP TABLE IF EXISTS workspace.sim_retail_demo.status_silver_ldp;

-- %% [markdown]
-- # Drop Python Pipeline (PL) Tables

-- %%
DROP TABLE IF EXISTS workspace.sim_retail_demo.customer_bronze_pl;
DROP TABLE IF EXISTS workspace.sim_retail_demo.customer_silver_pl;
DROP TABLE IF EXISTS workspace.sim_retail_demo.customers_bonze_clean_pl;
DROP TABLE IF EXISTS workspace.sim_retail_demo.gold_customer_order_history_pl;
DROP TABLE IF EXISTS workspace.sim_retail_demo.gold_orders_by_city_state_pl;
DROP TABLE IF EXISTS workspace.sim_retail_demo.gold_returns_by_customer_pl;
DROP TABLE IF EXISTS workspace.sim_retail_demo.orders_bronze_pl;
DROP TABLE IF EXISTS workspace.sim_retail_demo.orders_silver_pl;
DROP TABLE IF EXISTS workspace.sim_retail_demo.status_bronze_pl;
DROP TABLE IF EXISTS workspace.sim_retail_demo.status_silver_pl;

-- %% [markdown]
-- # Drop Pyspark Job Pipeline Tables

-- %%
DROP TABLE IF EXISTS workspace.sim_retail_demo.customer_bronze_pyspark;
DROP TABLE IF EXISTS workspace.sim_retail_demo.customers_bonze_clean_pyspark;
DROP TABLE IF EXISTS workspace.sim_retail_demo.customer_silver_pyspark;
DROP TABLE IF EXISTS workspace.sim_retail_demo.gold_customer_order_history_pyspark;
DROP TABLE IF EXISTS workspace.sim_retail_demo.gold_orders_by_city_state_pyspark;
DROP TABLE IF EXISTS workspace.sim_retail_demo.gold_returns_by_customer_pyspark;
DROP TABLE IF EXISTS workspace.sim_retail_demo.gold_current_orders_pyspark;
DROP TABLE IF EXISTS workspace.sim_retail_demo.orders_bronze_pyspark;
DROP TABLE IF EXISTS workspace.sim_retail_demo.orders_silver_pyspark;
DROP TABLE IF EXISTS workspace.sim_retail_demo.status_bronze_pyspark;
DROP TABLE IF EXISTS workspace.sim_retail_demo.status_silver_pyspark;
DROP TABLE IF EXISTS workspace.sim_retail_demo.temp_vw_bronze_customer_merge;
